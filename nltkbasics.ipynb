# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
example_txt="The focus of such an essay predicts its structure. It dictates the information readers need to know and the order in which they need to receive it. Thus your essay's structure is necessarily unique to the main claim you're making. Although there are guidelines for constructing certain classic essay types (e.g., comparative analysis), there are no set formula."
print(sent_tokenize(example_txt))

# %%
words=word_tokenize(example_txt)

# %%
# stopwords
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)

# %%
# filtered_sentence=[]
# for w in words:
#     if w not in stop_words:
#         filtered_sentence.append(w)
# print(filtered_sentence)
filtered_sentence=[w for w in words if w not in stop_words]
print(filtered_sentence)

# %%
# stemmer
from nltk.stem import PorterStemmer
ps=PorterStemmer()
example_words=["python","pythoner","pythoning","pythoned","pythonly"]
for w in example_words:
    print(ps.stem(w))

# %%
#pos tagging
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
train_txt=state_union.raw("aboutapj1.txt")
sample_txt=state_union.raw("aboutapj.txt")

# %%
custom_sent_tokenizer=PunktSentenceTokenizer(train_txt)
tokenized=custom_sent_tokenizer.tokenize(sample_txt)

# %%
def process_content():
    try:
        for i in tokenized:
            words=nltk.word_tokenize(i)
            tagged=nltk.pos_tag(words)
            print(tagged)
    except Exception as e:
        print(str(e))
process_content()
# Out:
# [('Kizie', 'NNP'), ('Basu', 'NNP'), ('is', 'VBZ'), ('fighting', 'VBG'), ('thyroid', 'JJ'), ('cancer', 'NN'), ('when', 'WRB'), ('she', 'PRP'), ('meets', 'VBZ'), ('Immanuel', 'NNP'), ("'Manny", 'NNP'), ("'", 'POS'), ('Rajkumar', 'NNP'), ('Junior', 'NNP'), (',', ','), ('who', 'WP'), ('has', 'VBZ'), ('previously', 'RB'), ('suffered', 'VBN'), ('from', 'IN'), ('osteosarcoma', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('in', 'IN'), ('remission', 'NN'), ('.', '.')]
# [('Manny', 'NNP'), ('and', 'CC'), ('his', 'PRP$'), ('friend', 'NN'), ('JP', 'NNP'), (',', ','), ('who', 'WP'), ('is', 'VBZ'), ('suffering', 'VBG'), ('from', 'IN'), ('glaucoma', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('blind', 'VBN'), ('in', 'IN'), ('one', 'CD'), ('eye', 'NN'), (',', ','), ('are', 'VBP'), ('making', 'VBG'), ('a', 'DT'), ('movie', 'NN'), ('together', 'RB'), (',', ','), ('inspired', 'VBN'), ('by', 'IN'), ('Rajinikanth', 'NNP'), ("'s", 'POS'), ('films', 'NNS'), ('.', '.')]
# [('Manny', 'NNP'), ('invites', 'VBZ'), ('Kizie', 'NNP'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('female', 'JJ'), ('lead', 'NN'), ('.', '.')]
# [('The', 'DT'), ('two', 'CD'), ('bond', 'NN'), ('over', 'IN'), ('his', 'PRP$'), ('love', 'NN'), ('for', 'IN'), ('Rajnikanth', 'NNP'), ("'s", 'POS'), ('movies', 'NNS'), ('and', 'CC'), ('her', 'PRP$'), ('love', 'NN'), ('for', 'IN'), ('music', 'NN'), (',', ','), ('specifically', 'RB'), ('an', 'DT'), ('incomplete', 'NN'), ('song', 'NN'), ('by', 'IN'), ('retired', 'JJ'), ('songwriter', 'NN'), ('Abhimanyu', 'NNP'), ('Veer', 'NNP'), ('.', '.')]
# [('Kizie', 'NNP'), ('and', 'CC'), ('Manny', 'NNP'), ('gradually', 'RB'), ('fall', 'VBP'), ('in', 'IN'), ('love', 'NN'), ('as', 'IN'), ('they', 'PRP'), ('shoot', 'VBP'), ('scenes', 'NNS'), ('for', 'IN'), ('JP', 'NNP'), ("'s", 'POS'), ('film', 'NN'), ('.', '.')]
# [('They', 'PRP'), ('decides', 'VBP'), ('to', 'TO'), ('make', 'VB'), ("'seri", 'NN'), ("'", "''"), (',', ','), ('the', 'DT'), ('Tamil', 'NNP'), ('word', 'NN'), ('for', 'IN'), ("'okay", 'NNP'), ("'", 'POS'), (',', ','), ('their', 'PRP$'), ('secret', 'JJ'), ('word', 'NN'), ('that', 'WDT'), ('will', 'MD'), ('help', 'VB'), ('them', 'PRP'), ('remember', 'VB'), ('that', 'IN'), ('everything', 'NN'), ('will', 'MD'), ('be', 'VB'), ('okay', 'VBN'), ('in', 'IN'), ('life', 'NN'), ('and', 'CC'), ('to', 'TO'), ('stay', 'VB'), ('positive', 'JJ'), ('.', '.')]
# [('After', 'IN'), ('an', 'DT'), ('operation', 'NN'), (',', ','), ('JP', 'NNP'), ('loses', 'VBZ'), ('sight', 'NN'), ('in', 'IN'), ('his', 'PRP$'), ('second', 'JJ'), ('eye', 'NN'), (',', ','), ('making', 'VBG'), ('him', 'PRP'), ('go', 'VB'), ('blind', 'NN'), ('.', '.')]
# [('One', 'CD'), ('day', 'NN'), (',', ','), ('Manny', 'NNP'), ('informs', 'VBZ'), ('Kizie', 'NNP'), ('that', 'IN'), ('he', 'PRP'), ('has', 'VBZ'), ('managed', 'VBN'), ('to', 'TO'), ('track', 'VB'), ('down', 'RP'), ('Abhimanyu', 'NNP'), ('Veer', 'NNP'), ('and', 'CC'), ('get', 'VB'), ('in', 'IN'), ('touch', 'NN'), ('with', 'IN'), ('him', 'PRP'), ('.', '.')]
# [('Kizie', 'NNP'), ('e-mails', 'JJ'), ('Veer', 'NNP'), (',', ','), ('who', 'WP'), ('replies', 'VBZ'), ('that', 'IN'), ('she', 'PRP'), ('can', 'MD'), ('visit', 'VB'), ('him', 'PRP'), ('in', 'IN'), ('Paris', 'NNP'), ('to', 'TO'), ('get', 'VB'), ('her', 'PRP$'), ('questions', 'NNS'), ('answered', 'VBN'), ('.', '.')]
# [('Kizie', 'NNP'), ('and', 'CC'), ('Manny', 'NNP'), ('convince', 'NN'), ('Kizie', 'NNP'), ("'s", 'POS'), ('parents', 'NNS'), ('to', 'TO'), ('allow', 'VB'), ('them', 'PRP'), ('to', 'TO'), ('take', 'VB'), ('the', 'DT'), ('trip', 'NN'), (',', ','), ('with', 'IN'), ('the', 'DT'), ('condition', 'NN'), ('that', 'IN'), ('Kizie', 'NNP'), ("'s", 'POS'), ('mother', 'NN'), ('joins', 'VBZ'), ('them', 'PRP'), ('.', '.')]
# [('As', 'IN'), ('they', 'PRP'), ('are', 'VBP'), ('making', 'VBG'), ('arrangements', 'NNS'), ('for', 'IN'), ('the', 'DT'), ('trip', 'NN'), (',', ','), ('Kizie', 'NNP'), ("'s", 'POS'), ('cancer', 'NN'), ('gets', 'VBZ'), ('worse', 'JJR'), ('and', 'CC'), ('she', 'PRP'), ('is', 'VBZ'), ('hospitalized', 'VBN'), ('.', '.')]
# [('After', 'IN'), ('her', 'PRP$'), ('recovery', 'NN'), (',', ','), ('she', 'PRP'), ('is', 'VBZ'), ('weakened', 'VBN'), ('and', 'CC'), ('initially', 'RB'), ('distances', 'NNS'), ('herself', 'PRP'), ('from', 'IN'), ('Manny', 'NNP'), ('but', 'CC'), ('later', 'RB'), ('relents', 'NNS'), ('.', '.')]
# [('They', 'PRP'), ('go', 'VBP'), ('to', 'TO'), ('Paris', 'NNP'), ('to', 'TO'), ('visit', 'VB'), ('Veer', 'NNP'), (',', ','), ('who', 'WP'), ('turns', 'VBZ'), ('out', 'RP'), ('to', 'TO'), ('have', 'VB'), ('no', 'DT'), ('conclusive', 'JJ'), ('answers', 'NNS'), (',', ','), ('disappointing', 'JJ'), ('Kizie', 'NNP'), ('.', '.')]
# [('Soon', 'RB'), ('after', 'IN'), (',', ','), ('Manny', 'NNP'), ('informs', 'VBZ'), ('Kizie', 'NNP'), ('that', 'IN'), ('his', 'PRP$'), ('cancer', 'NN'), ('had', 'VBD'), ('returned', 'VBN'), ('and', 'CC'), ('is', 'VBZ'), ('now', 'RB'), ('terminal', 'JJ'), ('.', '.')]
# [('As', 'IN'), ('Manny', 'NNP'), ("'s", 'POS'), ('health', 'NN'), ('deteriorates', 'NNS'), (',', ','), ('Kizie', 'NNP'), ('convinces', 'VBZ'), ('him', 'PRP'), ('and', 'CC'), ('JP', 'NNP'), ('to', 'TO'), ('finish', 'VB'), ('the', 'DT'), ('film', 'NN'), ('.', '.')]
# [('Manny', 'NNP'), ('then', 'RB'), ('invites', 'VBZ'), ('JP', 'NNP'), ('and', 'CC'), ('Kizie', 'NNP'), ('to', 'TO'), ('his', 'PRP$'), ('mock', 'NN'), ('funeral', 'NN'), (',', ','), ('where', 'WRB'), ('they', 'PRP'), ('deliver', 'VB'), ('eulogies', 'NNS'), ('that', 'IN'), ('they', 'PRP'), ('have', 'VBP'), ('both', 'DT'), ('prepared', 'VBN'), ('.', '.')]
# [('Manny', 'NNP'), ('dies', 'VBZ'), ('a', 'DT'), ('couple', 'NN'), ('of', 'IN'), ('days', 'NNS'), ('later', 'RB'), (',', ','), ('leaving', 'VBG'), ('a', 'DT'), ('letter', 'NN'), ('for', 'IN'), ('Kizie', 'NNP'), (',', ','), ('explaining', 'VBG'), ('that', 'IN'), ('he', 'PRP'), ('had', 'VBD'), ('finished', 'VBN'), ('Veer', 'NNP'), ("'s", 'POS'), ('song', 'NN'), ('for', 'IN'), ('her', 'PRP$'), ('and', 'CC'), ('had', 'VBD'), ('even', 'RB'), ('convinced', 'VBN'), ('Veer', 'NNP'), ('to', 'TO'), ('help', 'VB'), ('him', 'PRP'), ('finish', 'VB'), ('the', 'DT'), ('song', 'NN'), ('.', '.')]
# [('JP', 'NNP'), ("'s", 'POS'), ('finished', 'VBN'), ('film', 'NN'), ('premieres', 'NNS'), ('in', 'IN'), ('an', 'DT'), ('open', 'JJ'), ('air', 'NN'), ('theatre', 'NN'), (',', ','), ('where', 'WRB'), ('Kizie', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('crowd', 'JJ'), ('get', 'NN'), ('emotional', 'JJ'), ('.', '.')]
# [('In', 'IN'), ('the', 'DT'), ('final', 'JJ'), ('scene', 'NN'), ('of', 'IN'), ('the', 'DT'), ('film', 'NN'), (',', ','), ('Manny', 'NNP'), ('breaks', 'VBZ'), ('the', 'DT'), ('fourth', 'JJ'), ('wall', 'NN'), ('and', 'CC'), ('directly', 'RB'), ('speaks', 'VBZ'), ('to', 'TO'), ('Kizie', 'NNP'), (',', ','), ('to', 'TO'), ('which', 'WDT'), ('she', 'PRP'), ('replies', 'VBZ'), ('``', '``'), ('Seri', 'NNP'), ("''", "''"), ('.', '.')]

# %%
# chunking
def process_content():
    try:
        for i in tokenized:
            words=nltk.word_tokenize(i)
            tagged=nltk.pos_tag(words)
            chunkGram=r"""Chunk:{<RB.?>*<VB.?>*<NNP><NN>?}"""
            chunkParser=nltk.RegexpParser(chunkGram)
            chunked=chunkParser.parse(tagged)
            print(chunked)
            chunked.draw()
    except Exception as e:
        print(str(e))
process_content()
# Out:
# (S
#   (Chunk Kizie/NNP)
#   (Chunk Basu/NNP)
#   is/VBZ
#   fighting/VBG
#   thyroid/JJ
#   cancer/NN
#   when/WRB
#   she/PRP
#   (Chunk meets/VBZ Immanuel/NNP)
#   (Chunk 'Manny/NNP)
#   '/POS
#   (Chunk Rajkumar/NNP)
#   (Chunk Junior/NNP)
#   ,/,
#   who/WP
#   has/VBZ
#   previously/RB
#   suffered/VBN
#   from/IN
#   osteosarcoma/NN
#   and/CC
#   is/VBZ
#   in/IN
#   remission/NN
#   ./.)
# (S
#   (Chunk Manny/NNP)
#   and/CC
#   his/PRP$
#   friend/NN
#   (Chunk JP/NNP)
#   ,/,
#   who/WP
#   is/VBZ
#   suffering/VBG
#   from/IN
#   glaucoma/NN
#   and/CC
#   is/VBZ
#   blind/VBN
#   in/IN
#   one/CD
#   eye/NN
#   ,/,
#   are/VBP
#   making/VBG
#   a/DT
#   movie/NN
#   together/RB
#   ,/,
#   inspired/VBN
#   by/IN
#   (Chunk Rajinikanth/NNP)
#   's/POS
#   films/NNS
#   ./.)
# (S
#   (Chunk Manny/NNP)
#   (Chunk invites/VBZ Kizie/NNP)
#   to/TO
#   be/VB
#   the/DT
#   female/JJ
#   lead/NN
#   ./.)
# (S
#   The/DT
#   two/CD
#   bond/NN
#   over/IN
#   his/PRP$
#   love/NN
#   for/IN
#   (Chunk Rajnikanth/NNP)
#   's/POS
#   movies/NNS
#   and/CC
#   her/PRP$
#   love/NN
#   for/IN
#   music/NN
#   ,/,
#   specifically/RB
#   an/DT
#   incomplete/NN
#   song/NN
#   by/IN
#   retired/JJ
#   songwriter/NN
#   (Chunk Abhimanyu/NNP)
#   (Chunk Veer/NNP)
#   ./.)
# (S
#   (Chunk Kizie/NNP)
#   and/CC
#   (Chunk Manny/NNP)
#   gradually/RB
#   fall/VBP
#   in/IN
#   love/NN
#   as/IN
#   they/PRP
#   shoot/VBP
#   scenes/NNS
#   for/IN
#   (Chunk JP/NNP)
#   's/POS
#   film/NN
#   ./.)
# (S
#   They/PRP
#   decides/VBP
#   to/TO
#   make/VB
#   'seri/NN
#   '/''
#   ,/,
#   the/DT
#   (Chunk Tamil/NNP word/NN)
#   for/IN
#   (Chunk 'okay/NNP)
#   '/POS
#   ,/,
#   their/PRP$
#   secret/JJ
#   word/NN
#   that/WDT
#   will/MD
#   help/VB
#   them/PRP
#   remember/VB
#   that/IN
#   everything/NN
#   will/MD
#   be/VB
#   okay/VBN
#   in/IN
#   life/NN
#   and/CC
#   to/TO
#   stay/VB
#   positive/JJ
#   ./.)
# (S
#   After/IN
#   an/DT
#   operation/NN
#   ,/,
#   (Chunk JP/NNP)
#   loses/VBZ
#   sight/NN
#   in/IN
#   his/PRP$
#   second/JJ
#   eye/NN
#   ,/,
#   making/VBG
#   him/PRP
#   go/VB
#   blind/NN
#   ./.)
# (S
#   One/CD
#   day/NN
#   ,/,
#   (Chunk Manny/NNP)
#   (Chunk informs/VBZ Kizie/NNP)
#   that/IN
#   he/PRP
#   has/VBZ
#   managed/VBN
#   to/TO
#   track/VB
#   down/RP
#   (Chunk Abhimanyu/NNP)
#   (Chunk Veer/NNP)
#   and/CC
#   get/VB
#   in/IN
#   touch/NN
#   with/IN
#   him/PRP
#   ./.)
# (S
#   (Chunk Kizie/NNP)
#   e-mails/JJ
#   (Chunk Veer/NNP)
#   ,/,
#   who/WP
#   replies/VBZ
#   that/IN
#   she/PRP
#   can/MD
#   visit/VB
#   him/PRP
#   in/IN
#   (Chunk Paris/NNP)
#   to/TO
#   get/VB
#   her/PRP$
#   questions/NNS
#   answered/VBN
#   ./.)
# (S
#   (Chunk Kizie/NNP)
#   and/CC
#   (Chunk Manny/NNP convince/NN)
#   (Chunk Kizie/NNP)
#   's/POS
#   parents/NNS
#   to/TO
#   allow/VB
#   them/PRP
#   to/TO
#   take/VB
#   the/DT
#   trip/NN
#   ,/,
#   with/IN
#   the/DT
#   condition/NN
#   that/IN
#   (Chunk Kizie/NNP)
#   's/POS
#   mother/NN
#   joins/VBZ
#   them/PRP
#   ./.)
# (S
#   As/IN
#   they/PRP
#   are/VBP
#   making/VBG
#   arrangements/NNS
#   for/IN
#   the/DT
#   trip/NN
#   ,/,
#   (Chunk Kizie/NNP)
#   's/POS
#   cancer/NN
#   gets/VBZ
#   worse/JJR
#   and/CC
#   she/PRP
#   is/VBZ
#   hospitalized/VBN
#   ./.)
# (S
#   After/IN
#   her/PRP$
#   recovery/NN
#   ,/,
#   she/PRP
#   is/VBZ
#   weakened/VBN
#   and/CC
#   initially/RB
#   distances/NNS
#   herself/PRP
#   from/IN
#   (Chunk Manny/NNP)
#   but/CC
#   later/RB
#   relents/NNS
#   ./.)
# (S
#   They/PRP
#   go/VBP
#   to/TO
#   (Chunk Paris/NNP)
#   to/TO
#   (Chunk visit/VB Veer/NNP)
#   ,/,
#   who/WP
#   turns/VBZ
#   out/RP
#   to/TO
#   have/VB
#   no/DT
#   conclusive/JJ
#   answers/NNS
#   ,/,
#   disappointing/JJ
#   (Chunk Kizie/NNP)
#   ./.)
# (S
#   Soon/RB
#   after/IN
#   ,/,
#   (Chunk Manny/NNP)
#   (Chunk informs/VBZ Kizie/NNP)
#   that/IN
#   his/PRP$
#   cancer/NN
#   had/VBD
#   returned/VBN
#   and/CC
#   is/VBZ
#   now/RB
#   terminal/JJ
#   ./.)
# (S
#   As/IN
#   (Chunk Manny/NNP)
#   's/POS
#   health/NN
#   deteriorates/NNS
#   ,/,
#   (Chunk Kizie/NNP)
#   convinces/VBZ
#   him/PRP
#   and/CC
#   (Chunk JP/NNP)
#   to/TO
#   finish/VB
#   the/DT
#   film/NN
#   ./.)
# (S
#   (Chunk Manny/NNP)
#   (Chunk then/RB invites/VBZ JP/NNP)
#   and/CC
#   (Chunk Kizie/NNP)
#   to/TO
#   his/PRP$
#   mock/NN
#   funeral/NN
#   ,/,
#   where/WRB
#   they/PRP
#   deliver/VB
#   eulogies/NNS
#   that/IN
#   they/PRP
#   have/VBP
#   both/DT
#   prepared/VBN
#   ./.)
# (S
#   (Chunk Manny/NNP)
#   dies/VBZ
#   a/DT
#   couple/NN
#   of/IN
#   days/NNS
#   later/RB
#   ,/,
#   leaving/VBG
#   a/DT
#   letter/NN
#   for/IN
#   (Chunk Kizie/NNP)
#   ,/,
#   explaining/VBG
#   that/IN
#   he/PRP
#   (Chunk had/VBD finished/VBN Veer/NNP)
#   's/POS
#   song/NN
#   for/IN
#   her/PRP$
#   and/CC
#   had/VBD
#   (Chunk even/RB convinced/VBN Veer/NNP)
#   to/TO
#   help/VB
#   him/PRP
#   finish/VB
#   the/DT
#   song/NN
#   ./.)
# (S
#   (Chunk JP/NNP)
#   's/POS
#   finished/VBN
#   film/NN
#   premieres/NNS
#   in/IN
#   an/DT
#   open/JJ
#   air/NN
#   theatre/NN
#   ,/,
#   where/WRB
#   (Chunk Kizie/NNP)
#   and/CC
#   the/DT
#   crowd/JJ
#   get/NN
#   emotional/JJ
#   ./.)
# (S
#   In/IN
#   the/DT
#   final/JJ
#   scene/NN
#   of/IN
#   the/DT
#   film/NN
#   ,/,
#   (Chunk Manny/NNP)
#   breaks/VBZ
#   the/DT
#   fourth/JJ
#   wall/NN
#   and/CC
#   directly/RB
#   speaks/VBZ
#   to/TO
#   (Chunk Kizie/NNP)
#   ,/,
#   to/TO
#   which/WDT
#   she/PRP
#   replies/VBZ
#   ``/``
#   (Chunk Seri/NNP)
#   ''/''
#   ./.)

# %%
# chinking
def process_content():
    try:
        for i in tokenized:
            words=nltk.word_tokenize(i)
            tagged=nltk.pos_tag(words)
            chunkGram=r"""Chunk:{<.*>+}
                                }<VB.?|IN|DT|TO>+{"""
            chunkParser=nltk.RegexpParser(chunkGram)
            chunked=chunkParser.parse(tagged)
            print(chunked)
            chunked.draw()
    except Exception as e:
        print(str(e))
process_content()
# Out:
# (S
#   (Chunk Kizie/NNP Basu/NNP)
#   is/VBZ
#   fighting/VBG
#   (Chunk thyroid/JJ cancer/NN when/WRB she/PRP)
#   meets/VBZ
#   (Chunk
#     Immanuel/NNP
#     'Manny/NNP
#     '/POS
#     Rajkumar/NNP
#     Junior/NNP
#     ,/,
#     who/WP)
#   has/VBZ
#   (Chunk previously/RB)
#   suffered/VBN
#   from/IN
#   (Chunk osteosarcoma/NN and/CC)
#   is/VBZ
#   in/IN
#   (Chunk remission/NN ./.))
# (S
#   (Chunk Manny/NNP and/CC his/PRP$ friend/NN JP/NNP ,/, who/WP)
#   is/VBZ
#   suffering/VBG
#   from/IN
#   (Chunk glaucoma/NN and/CC)
#   is/VBZ
#   blind/VBN
#   in/IN
#   (Chunk one/CD eye/NN ,/,)
#   are/VBP
#   making/VBG
#   a/DT
#   (Chunk movie/NN together/RB ,/,)
#   inspired/VBN
#   by/IN
#   (Chunk Rajinikanth/NNP 's/POS films/NNS ./.))
# (S
#   (Chunk Manny/NNP)
#   invites/VBZ
#   (Chunk Kizie/NNP)
#   to/TO
#   be/VB
#   the/DT
#   (Chunk female/JJ lead/NN ./.))
# (S
#   The/DT
#   (Chunk two/CD bond/NN)
#   over/IN
#   (Chunk his/PRP$ love/NN)
#   for/IN
#   (Chunk Rajnikanth/NNP 's/POS movies/NNS and/CC her/PRP$ love/NN)
#   for/IN
#   (Chunk music/NN ,/, specifically/RB)
#   an/DT
#   (Chunk incomplete/NN song/NN)
#   by/IN
#   (Chunk retired/JJ songwriter/NN Abhimanyu/NNP Veer/NNP ./.))
# (S
#   (Chunk Kizie/NNP and/CC Manny/NNP gradually/RB)
#   fall/VBP
#   in/IN
#   (Chunk love/NN)
#   as/IN
#   (Chunk they/PRP)
#   shoot/VBP
#   (Chunk scenes/NNS)
#   for/IN
#   (Chunk JP/NNP 's/POS film/NN ./.))
# (S
#   (Chunk They/PRP)
#   decides/VBP
#   to/TO
#   make/VB
#   (Chunk 'seri/NN '/'' ,/,)
#   the/DT
#   (Chunk Tamil/NNP word/NN)
#   for/IN
#   (Chunk
#     'okay/NNP
#     '/POS
#     ,/,
#     their/PRP$
#     secret/JJ
#     word/NN
#     that/WDT
#     will/MD)
#   help/VB
#   (Chunk them/PRP)
#   remember/VB
#   that/IN
#   (Chunk everything/NN will/MD)
#   be/VB
#   okay/VBN
#   in/IN
#   (Chunk life/NN and/CC)
#   to/TO
#   stay/VB
#   (Chunk positive/JJ ./.))
# (S
#   After/IN
#   an/DT
#   (Chunk operation/NN ,/, JP/NNP)
#   loses/VBZ
#   (Chunk sight/NN)
#   in/IN
#   (Chunk his/PRP$ second/JJ eye/NN ,/,)
#   making/VBG
#   (Chunk him/PRP)
#   go/VB
#   (Chunk blind/NN ./.))
# (S
#   (Chunk One/CD day/NN ,/, Manny/NNP)
#   informs/VBZ
#   (Chunk Kizie/NNP)
#   that/IN
#   (Chunk he/PRP)
#   has/VBZ
#   managed/VBN
#   to/TO
#   track/VB
#   (Chunk down/RP Abhimanyu/NNP Veer/NNP and/CC)
#   get/VB
#   in/IN
#   (Chunk touch/NN)
#   with/IN
#   (Chunk him/PRP ./.))
# (S
#   (Chunk Kizie/NNP e-mails/JJ Veer/NNP ,/, who/WP)
#   replies/VBZ
#   that/IN
#   (Chunk she/PRP can/MD)
#   visit/VB
#   (Chunk him/PRP)
#   in/IN
#   (Chunk Paris/NNP)
#   to/TO
#   get/VB
#   (Chunk her/PRP$ questions/NNS)
#   answered/VBN
#   (Chunk ./.))
# (S
#   (Chunk
#     Kizie/NNP
#     and/CC
#     Manny/NNP
#     convince/NN
#     Kizie/NNP
#     's/POS
#     parents/NNS)
#   to/TO
#   allow/VB
#   (Chunk them/PRP)
#   to/TO
#   take/VB
#   the/DT
#   (Chunk trip/NN ,/,)
#   with/IN
#   the/DT
#   (Chunk condition/NN)
#   that/IN
#   (Chunk Kizie/NNP 's/POS mother/NN)
#   joins/VBZ
#   (Chunk them/PRP ./.))
# (S
#   As/IN
#   (Chunk they/PRP)
#   are/VBP
#   making/VBG
#   (Chunk arrangements/NNS)
#   for/IN
#   the/DT
#   (Chunk trip/NN ,/, Kizie/NNP 's/POS cancer/NN)
#   gets/VBZ
#   (Chunk worse/JJR and/CC she/PRP)
#   is/VBZ
#   hospitalized/VBN
#   (Chunk ./.))
# (S
#   After/IN
#   (Chunk her/PRP$ recovery/NN ,/, she/PRP)
#   is/VBZ
#   weakened/VBN
#   (Chunk and/CC initially/RB distances/NNS herself/PRP)
#   from/IN
#   (Chunk Manny/NNP but/CC later/RB relents/NNS ./.))
# (S
#   (Chunk They/PRP)
#   go/VBP
#   to/TO
#   (Chunk Paris/NNP)
#   to/TO
#   visit/VB
#   (Chunk Veer/NNP ,/, who/WP)
#   turns/VBZ
#   (Chunk out/RP)
#   to/TO
#   have/VB
#   no/DT
#   (Chunk
#     conclusive/JJ
#     answers/NNS
#     ,/,
#     disappointing/JJ
#     Kizie/NNP
#     ./.))
# (S
#   (Chunk Soon/RB)
#   after/IN
#   (Chunk ,/, Manny/NNP)
#   informs/VBZ
#   (Chunk Kizie/NNP)
#   that/IN
#   (Chunk his/PRP$ cancer/NN)
#   had/VBD
#   returned/VBN
#   (Chunk and/CC)
#   is/VBZ
#   (Chunk now/RB terminal/JJ ./.))
# (S
#   As/IN
#   (Chunk Manny/NNP 's/POS health/NN deteriorates/NNS ,/, Kizie/NNP)
#   convinces/VBZ
#   (Chunk him/PRP and/CC JP/NNP)
#   to/TO
#   finish/VB
#   the/DT
#   (Chunk film/NN ./.))
# (S
#   (Chunk Manny/NNP then/RB)
#   invites/VBZ
#   (Chunk JP/NNP and/CC Kizie/NNP)
#   to/TO
#   (Chunk his/PRP$ mock/NN funeral/NN ,/, where/WRB they/PRP)
#   deliver/VB
#   (Chunk eulogies/NNS)
#   that/IN
#   (Chunk they/PRP)
#   have/VBP
#   both/DT
#   prepared/VBN
#   (Chunk ./.))
# (S
#   (Chunk Manny/NNP)
#   dies/VBZ
#   a/DT
#   (Chunk couple/NN)
#   of/IN
#   (Chunk days/NNS later/RB ,/,)
#   leaving/VBG
#   a/DT
#   (Chunk letter/NN)
#   for/IN
#   (Chunk Kizie/NNP ,/,)
#   explaining/VBG
#   that/IN
#   (Chunk he/PRP)
#   had/VBD
#   finished/VBN
#   (Chunk Veer/NNP 's/POS song/NN)
#   for/IN
#   (Chunk her/PRP$ and/CC)
#   had/VBD
#   (Chunk even/RB)
#   convinced/VBN
#   (Chunk Veer/NNP)
#   to/TO
#   help/VB
#   (Chunk him/PRP)
#   finish/VB
#   the/DT
#   (Chunk song/NN ./.))
# (S
#   (Chunk JP/NNP 's/POS)
#   finished/VBN
#   (Chunk film/NN premieres/NNS)
#   in/IN
#   an/DT
#   (Chunk open/JJ air/NN theatre/NN ,/, where/WRB Kizie/NNP and/CC)
#   the/DT
#   (Chunk crowd/JJ get/NN emotional/JJ ./.))
# (S
#   In/IN
#   the/DT
#   (Chunk final/JJ scene/NN)
#   of/IN
#   the/DT
#   (Chunk film/NN ,/, Manny/NNP)
#   breaks/VBZ
#   the/DT
#   (Chunk fourth/JJ wall/NN and/CC directly/RB)
#   speaks/VBZ
#   to/TO
#   (Chunk Kizie/NNP ,/,)
#   to/TO
#   (Chunk which/WDT she/PRP)
#   replies/VBZ
#   (Chunk ``/`` Seri/NNP ''/'' ./.))

# %%
# nammmed entity
def process_content():
    try:
        for i in tokenized:
            words=nltk.word_tokenize(i)
            tagged=nltk.pos_tag(words)
            named_ent=nltk.ne_chunk(tagged,binary=True)
            print(named_ent)
            named_ent.draw()
    except Exception as e:
        print(str(e))
process_content()
# Out:
# (S
#   (NE Kizie/NNP Basu/NNP)
#   is/VBZ
#   fighting/VBG
#   thyroid/JJ
#   cancer/NN
#   when/WRB
#   she/PRP
#   meets/VBZ
#   (NE Immanuel/NNP)
#   'Manny/NNP
#   '/POS
#   (NE Rajkumar/NNP Junior/NNP)
#   ,/,
#   who/WP
#   has/VBZ
#   previously/RB
#   suffered/VBN
#   from/IN
#   osteosarcoma/NN
#   and/CC
#   is/VBZ
#   in/IN
#   remission/NN
#   ./.)
# (S
#   (NE Manny/NNP)
#   and/CC
#   his/PRP$
#   friend/NN
#   JP/NNP
#   ,/,
#   who/WP
#   is/VBZ
#   suffering/VBG
#   from/IN
#   glaucoma/NN
#   and/CC
#   is/VBZ
#   blind/VBN
#   in/IN
#   one/CD
#   eye/NN
#   ,/,
#   are/VBP
#   making/VBG
#   a/DT
#   movie/NN
#   together/RB
#   ,/,
#   inspired/VBN
#   by/IN
#   (NE Rajinikanth/NNP)
#   's/POS
#   films/NNS
#   ./.)
# (S
#   (NE Manny/NNP)
#   invites/VBZ
#   (NE Kizie/NNP)
#   to/TO
#   be/VB
#   the/DT
#   female/JJ
#   lead/NN
#   ./.)
# (S
#   The/DT
#   two/CD
#   bond/NN
#   over/IN
#   his/PRP$
#   love/NN
#   for/IN
#   (NE Rajnikanth/NNP)
#   's/POS
#   movies/NNS
#   and/CC
#   her/PRP$
#   love/NN
#   for/IN
#   music/NN
#   ,/,
#   specifically/RB
#   an/DT
#   incomplete/NN
#   song/NN
#   by/IN
#   retired/JJ
#   songwriter/NN
#   (NE Abhimanyu/NNP Veer/NNP)
#   ./.)
# (S
#   (NE Kizie/NNP)
#   and/CC
#   (NE Manny/NNP)
#   gradually/RB
#   fall/VBP
#   in/IN
#   love/NN
#   as/IN
#   they/PRP
#   shoot/VBP
#   scenes/NNS
#   for/IN
#   (NE JP/NNP)
#   's/POS
#   film/NN
#   ./.)
# (S
#   They/PRP
#   decides/VBP
#   to/TO
#   make/VB
#   'seri/NN
#   '/''
#   ,/,
#   the/DT
#   (NE Tamil/NNP)
#   word/NN
#   for/IN
#   'okay/NNP
#   '/POS
#   ,/,
#   their/PRP$
#   secret/JJ
#   word/NN
#   that/WDT
#   will/MD
#   help/VB
#   them/PRP
#   remember/VB
#   that/IN
#   everything/NN
#   will/MD
#   be/VB
#   okay/VBN
#   in/IN
#   life/NN
#   and/CC
#   to/TO
#   stay/VB
#   positive/JJ
#   ./.)
# (S
#   After/IN
#   an/DT
#   operation/NN
#   ,/,
#   (NE JP/NNP)
#   loses/VBZ
#   sight/NN
#   in/IN
#   his/PRP$
#   second/JJ
#   eye/NN
#   ,/,
#   making/VBG
#   him/PRP
#   go/VB
#   blind/NN
#   ./.)
# (S
#   One/CD
#   day/NN
#   ,/,
#   (NE Manny/NNP)
#   informs/VBZ
#   Kizie/NNP
#   that/IN
#   he/PRP
#   has/VBZ
#   managed/VBN
#   to/TO
#   track/VB
#   down/RP
#   (NE Abhimanyu/NNP Veer/NNP)
#   and/CC
#   get/VB
#   in/IN
#   touch/NN
#   with/IN
#   him/PRP
#   ./.)
# (S
#   (NE Kizie/NNP)
#   e-mails/JJ
#   Veer/NNP
#   ,/,
#   who/WP
#   replies/VBZ
#   that/IN
#   she/PRP
#   can/MD
#   visit/VB
#   him/PRP
#   in/IN
#   (NE Paris/NNP)
#   to/TO
#   get/VB
#   her/PRP$
#   questions/NNS
#   answered/VBN
#   ./.)
# (S
#   (NE Kizie/NNP)
#   and/CC
#   (NE Manny/NNP)
#   convince/NN
#   (NE Kizie/NNP)
#   's/POS
#   parents/NNS
#   to/TO
#   allow/VB
#   them/PRP
#   to/TO
#   take/VB
#   the/DT
#   trip/NN
#   ,/,
#   with/IN
#   the/DT
#   condition/NN
#   that/IN
#   (NE Kizie/NNP)
#   's/POS
#   mother/NN
#   joins/VBZ
#   them/PRP
#   ./.)
# (S
#   As/IN
#   they/PRP
#   are/VBP
#   making/VBG
#   arrangements/NNS
#   for/IN
#   the/DT
#   trip/NN
#   ,/,
#   (NE Kizie/NNP)
#   's/POS
#   cancer/NN
#   gets/VBZ
#   worse/JJR
#   and/CC
#   she/PRP
#   is/VBZ
#   hospitalized/VBN
#   ./.)
# (S
#   After/IN
#   her/PRP$
#   recovery/NN
#   ,/,
#   she/PRP
#   is/VBZ
#   weakened/VBN
#   and/CC
#   initially/RB
#   distances/NNS
#   herself/PRP
#   from/IN
#   Manny/NNP
#   but/CC
#   later/RB
#   relents/NNS
#   ./.)
# (S
#   They/PRP
#   go/VBP
#   to/TO
#   (NE Paris/NNP)
#   to/TO
#   visit/VB
#   (NE Veer/NNP)
#   ,/,
#   who/WP
#   turns/VBZ
#   out/RP
#   to/TO
#   have/VB
#   no/DT
#   conclusive/JJ
#   answers/NNS
#   ,/,
#   disappointing/JJ
#   Kizie/NNP
#   ./.)
# (S
#   Soon/RB
#   after/IN
#   ,/,
#   (NE Manny/NNP)
#   informs/VBZ
#   Kizie/NNP
#   that/IN
#   his/PRP$
#   cancer/NN
#   had/VBD
#   returned/VBN
#   and/CC
#   is/VBZ
#   now/RB
#   terminal/JJ
#   ./.)
# (S
#   As/IN
#   (NE Manny/NNP)
#   's/POS
#   health/NN
#   deteriorates/NNS
#   ,/,
#   (NE Kizie/NNP)
#   convinces/VBZ
#   him/PRP
#   and/CC
#   JP/NNP
#   to/TO
#   finish/VB
#   the/DT
#   film/NN
#   ./.)
# (S
#   (NE Manny/NNP)
#   then/RB
#   invites/VBZ
#   JP/NNP
#   and/CC
#   (NE Kizie/NNP)
#   to/TO
#   his/PRP$
#   mock/NN
#   funeral/NN
#   ,/,
#   where/WRB
#   they/PRP
#   deliver/VB
#   eulogies/NNS
#   that/IN
#   they/PRP
#   have/VBP
#   both/DT
#   prepared/VBN
#   ./.)
# (S
#   (NE Manny/NNP)
#   dies/VBZ
#   a/DT
#   couple/NN
#   of/IN
#   days/NNS
#   later/RB
#   ,/,
#   leaving/VBG
#   a/DT
#   letter/NN
#   for/IN
#   (NE Kizie/NNP)
#   ,/,
#   explaining/VBG
#   that/IN
#   he/PRP
#   had/VBD
#   finished/VBN
#   (NE Veer/NNP)
#   's/POS
#   song/NN
#   for/IN
#   her/PRP$
#   and/CC
#   had/VBD
#   even/RB
#   convinced/VBN
#   (NE Veer/NNP)
#   to/TO
#   help/VB
#   him/PRP
#   finish/VB
#   the/DT
#   song/NN
#   ./.)
# (S
#   (NE JP/NNP)
#   's/POS
#   finished/VBN
#   film/NN
#   premieres/NNS
#   in/IN
#   an/DT
#   open/JJ
#   air/NN
#   theatre/NN
#   ,/,
#   where/WRB
#   (NE Kizie/NNP)
#   and/CC
#   the/DT
#   crowd/JJ
#   get/NN
#   emotional/JJ
#   ./.)
# (S
#   In/IN
#   the/DT
#   final/JJ
#   scene/NN
#   of/IN
#   the/DT
#   film/NN
#   ,/,
#   (NE Manny/NNP)
#   breaks/VBZ
#   the/DT
#   fourth/JJ
#   wall/NN
#   and/CC
#   directly/RB
#   speaks/VBZ
#   to/TO
#   (NE Kizie/NNP)
#   ,/,
#   to/TO
#   which/WDT
#   she/PRP
#   replies/VBZ
#   ``/``
#   Seri/NNP
#   ''/''
#   ./.)

# %%
# lemmatizing
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
# default position is noun
print(lemmatizer.lemmatize("cats"))
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("geese"))
print(lemmatizer.lemmatize("rocks"))
# position adjective
print(lemmatizer.lemmatize("better",pos="a"))
print(lemmatizer.lemmatize("best",pos="a"))
print(lemmatizer.lemmatize("run"))
# position verb
print(lemmatizer.lemmatize("run","v"))
# Out:
# cat
# cactus
# goose
# rock
# good
# best
# run
# run

# %%
# corpora
# corpus data search for %appdata% ->nltk_data
from nltk.corpus import abc
sample=abc.raw("science.txt")
tokens=sent_tokenize(sample)
print(tokens[1:10])
# Out:
# ["That's the conclusion of two studies published in this week's issue of The New England Journal of Medicine.", 'They found that inhaling a mist with a salt content of 7 or 9% improved lung function and, in some cases, produced less absenteeism from school or work.', 'Cystic fibrosis, a progressive and frequently fatal genetic disease that affects about 30,000 young adults and children in the US alone, is marked by a thickening of the mucus which makes it harder to clear the lungs of debris and bacteria.', 'The salt water solution "really opens up a new avenue for approaching patients with cystic fibrosis and how to treat them," says Dr Gail Weinmann, of the US National Heart, Lung, and Blood Institute, which sponsored one of the studies.', 'Mark Elkins of the Royal Prince Alfred Hospital in Sydney, Australia and colleagues authored one of the new published studies.', 'The team found that the 83 volunteers who regularly inhaled a 7% mist of salty water had fewer breathing problems and less absenteeism from school or work than those who inhaled a solution with a salt content of under 1%.', '"Adding salt [and water] to the airway surfaces of patients with cystic fibrosis is beneficial" for both children and adults, they conclude.', 'All of the patients first inhaled a chemical to try to open their lung passages as much as possible.', 'In the second study, US-based Assistant Profsesor Scott Donaldson of the University of North Carolina at Chapel Hill and his colleagues found that a 7% salt mist "produced a sustained acceleration of mucus clearance and improved lung function" because it helped hydrate the lungs.']

# %%
# Wordnet
# synset - interface to look up words in wordnet 
from nltk.corpus import wordnet
syns=wordnet.synsets("great")

# whole synset
print(syns[0].name())

# only the word
print(syns[0].lemmas()[0].name())

# definition
print(syns[0].definition())

# examples
print(syns[0].examples())
# Out:
# great.n.01
# great
# a person who has achieved distinction and honor in some field
# ['he is one of the greats of American music']

# %%
# synonyms and antonyms using wordnet
synonyms=[]
antonyms=[]
for syn in wordnet.synsets("good"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
print(set(synonyms))
print(set(antonyms))
# Out:
# {'estimable', 'honorable', 'adept', 'dear', 'near', 'undecomposed', 'expert', 'goodness', 'soundly', 'in_effect', 'beneficial', 'unspoilt', 'salutary', 'sound', 'in_force', 'skillful', 'well', 'upright', 'proficient', 'full', 'trade_good', 'secure', 'unspoiled', 'good', 'just', 'right', 'honest', 'respectable', 'thoroughly', 'commodity', 'dependable', 'effective', 'serious', 'practiced', 'safe', 'ripe', 'skilful'}
# {'bad', 'evilness', 'ill', 'badness', 'evil'}

# %%
# semantic similarity between words
w1=wordnet.synset("ship.n.01")
w2=wordnet.synset("boat.n.01")
print(w1.wup_similarity(w2))

w1=wordnet.synset("ship.n.01")
w2=wordnet.synset("car.n.01")
print(w1.wup_similarity(w2))

w1=wordnet.synset("ship.n.01")
w2=wordnet.synset("cactus.n.01")
print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091
# 0.6956521739130435
# 0.38095238095238093
